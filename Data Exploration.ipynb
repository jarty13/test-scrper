# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as mlt
import seaborn as sns
import os

# %%
aisles = pd.read_csv('aisles.csv')
departments = pd.read_csv('departments.csv')
orders= pd.read_csv('orders.csv')
products=pd.read_csv('products.csv')

# %%
aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
departments.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
total = pd.merge(products,departments, on='department_id')

# %%
total = pd.merge(total, aisles, on= 'aisle_id')

# %%
total.head()
# Out:
#    product_id                                    product_name  aisle_id  \
# 0           1                      Chocolate Sandwich Cookies        61
# 1          78               Nutter Butter Cookie Bites Go-Pak        61
# 2         102                           Danish Butter Cookies        61
# 3         172  Gluten Free All Natural Chocolate Chip Cookies        61
# 4         285                    Mini Nilla Wafers Munch Pack        61
#
#    department_id department          aisle
# 0             19     snacks  cookies cakes
# 1             19     snacks  cookies cakes
# 2             19     snacks  cookies cakes
# 3             19     snacks  cookies cakes
# 4             19     snacks  cookies cakes

# %%
order_prior = pd.read_csv('order_products__prior.csv')

# %%
order_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
total_order= pd.merge(total, order_prior, on='product_id')

# %%
total_order= pd.merge(total_order, orders, on='order_id', sort= True)

# %%
total_order.head()
# Out:
#    product_id                              product_name  aisle_id  \
# 0        9327                             Garlic Powder       104
# 1       40141          Original Unflavored Gelatine Mix       105
# 2        1819  All Natural No Stir Creamy Almond Butter        88
# 3       45918                            Coconut Butter        19
# 4       30035                         Natural Sweetener        17
#
#    department_id department                       aisle  order_id  \
# 0             13     pantry           spices seasonings         2
# 1             13     pantry  doughs gelatins bake mixes         2
# 2             13     pantry                     spreads         2
# 3             13     pantry               oils vinegars         2
# 4             13     pantry          baking ingredients         2
#
#    add_to_cart_order  reordered  user_id eval_set  order_number  order_dow  \
# 0                  3          0   202279    prior             3          5
# ...
